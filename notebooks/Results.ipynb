# %%
import pandas as pd

results = pd.read_csv("/Users/hindy/Desktop/Academics/MIT/MIT MBAn/Machine Learning under a Modern Optimization Lens/Mercor-AI-detection/model_results.csv")
results.columns
# Out:
# Index(['timestamp', 'model_name', 'notebook_name', 'model_type', 'features',
#        'early_stopping', 'feature_engineering', 'learning_rate', 'notes',
#        'optimizer', 'preprocessing', 'split_method', 'test_size', 'train_size',
#        'training_config_json', 'upsampling', 'val_accuracy', 'val_f1',
#        'val_precision', 'val_recall', 'val_roc_auc', 'val_size'],
#       dtype='object')

# %%
results.head()
# Out:
#              timestamp                   model_name    notebook_name  \
# 0  2025-11-14 15:54:05        RandomForest_baseline  heuristic_model
# 1  2025-11-14 15:54:05             XGBoost_baseline  heuristic_model
# 2  2025-11-14 15:54:05  LogisticRegression_baseline  heuristic_model
# 3  2025-11-14 15:56:19        RandomForest_baseline  heuristic_model
# 4  2025-11-14 15:56:19             XGBoost_baseline  heuristic_model
#
#            model_type            features early_stopping  \
# 0        RandomForest  Meta features (25)          False
# 1             XGBoost  Meta features (25)          False
# 2  LogisticRegression  Meta features (25)          False
# 3        RandomForest  Meta features (25)          False
# 4             XGBoost  Meta features (25)          False
#
#                           feature_engineering  learning_rate  \
# 0  extract_text_features() - 25 meta features            NaN
# 1  extract_text_features() - 25 meta features            0.1
# ...
